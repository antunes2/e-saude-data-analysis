# %%
import pandas as pd
import openpyxl

# %%
df_outubro = pd.read_csv('../data/raw/2025-10-06_Sistema_E-Saude_Medicos_-_Base_de_Dados.csv', sep=';', encoding='latin-1', low_memory=False)

# %%
df_outubro.head(350).to_excel('../data/processed/preview_outubro.xlsx', index=False)

# %%
df_clima = pd.read_csv('../data/raw/clima/dados_A807_H_2025-01-01_2025-10-31.csv', sep=';', encoding='latin-1', skiprows=10, low_memory=False)

column_mapping = {
            'Data Medicao': 'data_medicao',
            'Hora Medicao': 'hora_medicao',
            'TEMPERATURA DO AR - BULBO SECO, HORARIA(Â°C)': 'temp_atual',
            'TEMPERATURA MAXIMA NA HORA ANT. (AUT)(Â°C)': 'temp_max',
            'TEMPERATURA MINIMA NA HORA ANT. (AUT)(Â°C)': 'temp_min'
        }

df_clima.rename(columns=column_mapping, inplace=True)

df_clima.head(15)
# Out:
#    Data Medicao  Hora Medicao  TEMPERATURA DO AR - BULBO SECO, HORARIA(Â°C)  \
# 0    2025-01-01             0                                          20.3
# 1    2025-01-01           100                                          20.0
# 2    2025-01-01           200                                          19.7
# 3    2025-01-01           300                                          19.7
# 4    2025-01-01           400                                          19.4
# 5    2025-01-01           500                                          19.2
# 6    2025-01-01           600                                          19.2
# 7    2025-01-01           700                                          19.1
# 8    2025-01-01           800                                          18.4
# 9    2025-01-01           900                                          18.0
# 10   2025-01-01          1000                                          18.4
# ...

# %%
from scripts.climate_pipeline import ClimateETLPipeline


pipeline = ClimateETLPipeline()
pipeline.run()
# Out:
# 🌤️  Iniciando pipeline climático...
# 📥 Extraindo dados climáticos...
#    Encontrados 1 arquivos CSV
#    Lendo: dados_A807_H_2025-01-01_2025-10-31.csv
# 🛠️  Transformando dados climáticos...
# ❌ Erro no pipeline climático: 'temp_atual'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gabri\OneDrive\Documents\e-saude-data-analysis\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
