# %%
import pandas as pd
import openpyxl

# %%
df_outubro = pd.read_csv('../data/raw/2025-10-06_Sistema_E-Saude_Medicos_-_Base_de_Dados.csv', sep=';', encoding='latin-1', low_memory=False)

# %%
df_outubro.head(350).to_excel('../data/processed/preview_outubro.xlsx', index=False)

# %%
df_clima = pd.read_csv('../data/raw/clima/dados_A807_H_2025-01-01_2025-10-31.csv', sep=';', encoding='latin-1', skiprows=10, low_memory=False)
df_clima.head(15)
# Out:
#    Data Medicao  Hora Medicao  TEMPERATURA DO AR - BULBO SECO, HORARIA(Â°C)  \
# 0    2025-01-01             0                                          20.3
# 1    2025-01-01           100                                          20.0
# 2    2025-01-01           200                                          19.7
# 3    2025-01-01           300                                          19.7
# 4    2025-01-01           400                                          19.4
# 5    2025-01-01           500                                          19.2
# 6    2025-01-01           600                                          19.2
# 7    2025-01-01           700                                          19.1
# 8    2025-01-01           800                                          18.4
# 9    2025-01-01           900                                          18.0
# 10   2025-01-01          1000                                          18.4
# 11   2025-01-01          1100                                          19.6
# 12   2025-01-01          1200                                          21.6
# 13   2025-01-01          1300                                          23.4
# 14   2025-01-01          1400                                          24.9
#
#     TEMPERATURA MAXIMA NA HORA ANT. (AUT)(Â°C)  \
# 0                                         20.4
# 1                                         20.4
# 2                                         20.0
# 3                                         19.8
# 4                                         19.7
# 5                                         19.5
# 6                                         19.2
# 7                                         19.3
# 8                                         19.1
# 9                                         18.4
# 10                                        18.4
# 11                                        19.6
# 12                                        21.6
# 13                                        23.5
# 14                                        25.7
#
#     TEMPERATURA MINIMA NA HORA ANT. (AUT)(Â°C)  Unnamed: 5
# 0                                         20.2         NaN
# 1                                         20.0         NaN
# 2                                         19.6         NaN
# 3                                         19.7         NaN
# 4                                         19.4         NaN
# 5                                         19.1         NaN
# 6                                         19.1         NaN
# 7                                         19.1         NaN
# 8                                         18.4         NaN
# 9                                         18.0         NaN
# 10                                        18.0         NaN
# 11                                        18.4         NaN
# 12                                        19.3         NaN
# 13                                        20.8         NaN
# 14                                        23.2         NaN

# %%
from scripts.climate_pipeline import ClimateETLPipeline
import os 
from pathlib import Path

pipeline = ClimateETLPipeline()
pipeline.extract()
# Out:
# 🌤️  Iniciando pipeline climático...
# 📥 Fase 1 - Extraindo dados climáticos...
# ❌ Erro no pipeline climático: Nenhum CSV encontrado em data\raw\clima
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 6
#       3 from pathlib import Path
#       5 pipeline = ClimateETLPipeline()
# ----> 6 pipeline.run()
#
# File ~\OneDrive\Documents\e-saude-data-analysis\scripts\climate_pipeline.py:33, in ClimateETLPipeline.run(self)
#      30 print("🌤️  Iniciando pipeline climático...")
#      32 try:
# ---> 33     self.extract()
#      34     self.transform()
#      35     self.load()
#
# File ~\OneDrive\Documents\e-saude-data-analysis\scripts\climate_pipeline.py:51, in ClimateETLPipeline.extract(self)
#      48 csv_files = list(self.raw_data_path.glob('*.csv'))
#      50 if not csv_files:
# ---> 51     raise FileNotFoundError(f"Nenhum CSV encontrado em {self.raw_data_path}")
#      53 print(f"   Encontrados {len(csv_files)} arquivos XLSX")
#      55 dataframes = []
#
# FileNotFoundError: Nenhum CSV encontrado em data\raw\clima
